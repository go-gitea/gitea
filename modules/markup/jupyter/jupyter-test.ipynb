# %%
print('hello')
# Out:
# stdout 1 ...
# stdout 2 ...
# stderr ...

# %% [markdown]
# # h1
# ## h2
# ### h3
#
# paragraph 1
#
# paragraph 2
# - list item 1
# - list item 2
#
# ```python
# print('code block')
# ```
# <table><tr><th>th1</th><th>th2</th></tr><tr><td>td1</td><td>td2</td></tr></table>
