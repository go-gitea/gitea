# %%
print('very-looooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooong')
# Out:
# stdout 1 ...
# stdout 2 ...
# stderr ...
# data text 1
# data text 2
# <a href='/'>HTML Link</a>
# $$a=1$$
# plain text
# stacktrace 1
# stacktrace 2

# %% [markdown]
# # h1
# ## h2
# ### h3
#
# paragraph 1
#
# very-looooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooong
# - list item 1
# - list item 2
#
# ```python
# print('code block')
# ```
# <table><tr><th>th1</th><th>th2</th></tr><tr><td>td1</td><td>td2</td></tr></table>
